# %%
import numpy as np
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.ml.feature import VectorAssembler

sc = SparkContext.getOrCreate()
ss = SparkSession.builder.getOrCreate()

# %%
train = ss.read.csv("X_train.csv", inferSchema=True, header=True)

# %%
train.printSchema()
# Out:
# root
#  |-- num_prev_so: integer (nullable = true)
#  |-- mean_amp_prev_so: double (nullable = true)
#  |-- mean_duration_prev_so: double (nullable = true)
#  |-- amp_curr_so: double (nullable = true)
#  |-- duration_curr_so: integer (nullable = true)
#  |-- curr_sleep_stage: integer (nullable = true)
#  |-- time_elapsed_since_asleep: integer (nullable = true)
#  |-- time_deep_sleep: integer (nullable = true)
#  |-- time_light_sleep: integer (nullable = true)
#  |-- time_rem_sleep: integer (nullable = true)
#  |-- time_wake_sleep: integer (nullable = true)
#  |-- eeg1: double (nullable = true)
#  |-- eeg2: double (nullable = true)
#  |-- eeg3: double (nullable = true)
#  |-- eeg4: double (nullable = true)
#  |-- eeg5: double (nullable = true)
#  |-- eeg6: double (nullable = true)
#  |-- eeg7: double (nullable = true)
#  |-- eeg8: double (nullable = true)
#  |-- eeg9: double (nullable = true)
#  |-- eeg10: double (nullable = true)
#  |-- eeg11: double (nullable = true)
#  |-- eeg12: double (nullable = true)
#  |-- eeg13: double (nullable = true)
#  |-- eeg14: double (nullable = true)
#  |-- eeg15: double (nullable = true)
#  |-- eeg16: double (nullable = true)
#  |-- eeg17: double (nullable = true)
#  |-- eeg18: double (nullable = true)
#  |-- eeg19: double (nullable = true)
#  |-- eeg20: double (nullable = true)
#  |-- eeg21: double (nullable = true)
#  |-- eeg22: double (nullable = true)
#  |-- eeg23: double (nullable = true)
#  |-- eeg24: double (nullable = true)
#  |-- eeg25: double (nullable = true)
#  |-- eeg26: double (nullable = true)
#  |-- eeg27: double (nullable = true)
#  |-- eeg28: double (nullable = true)
#  |-- eeg29: double (nullable = true)
#  |-- eeg30: double (nullable = true)
#  |-- eeg31: double (nullable = true)
#  |-- eeg32: double (nullable = true)
#  |-- eeg33: double (nullable = true)
#  |-- eeg34: double (nullable = true)
#  |-- eeg35: double (nullable = true)
#  |-- eeg36: double (nullable = true)
#  |-- eeg37: double (nullable = true)
#  |-- eeg38: double (nullable = true)
#  |-- eeg39: double (nullable = true)
#  |-- eeg40: double (nullable = true)
#  |-- eeg41: double (nullable = true)
#  |-- eeg42: double (nullable = true)
#  |-- eeg43: double (nullable = true)
#  |-- eeg44: double (nullable = true)
#  |-- eeg45: double (nullable = true)
#  |-- eeg46: double (nullable = true)
#  |-- eeg47: double (nullable = true)
#  |-- eeg48: double (nullable = true)
#  |-- eeg49: double (nullable = true)
#  |-- eeg50: double (nullable = true)
#  |-- eeg51: double (nullable = true)
#  |-- eeg52: double (nullable = true)
#  |-- eeg53: double (nullable = true)
#  |-- eeg54: double (nullable = true)
#  |-- eeg55: double (nullable = true)
#  |-- eeg56: double (nullable = true)
#  |-- eeg57: double (nullable = true)
#  |-- eeg58: double (nullable = true)
#  |-- eeg59: double (nullable = true)
#  |-- eeg60: double (nullable = true)
#  |-- eeg61: double (nullable = true)
#  |-- eeg62: double (nullable = true)
#  |-- eeg63: double (nullable = true)
#  |-- eeg64: double (nullable = true)
#  |-- eeg65: double (nullable = true)
#  |-- eeg66: double (nullable = true)
#  |-- eeg67: double (nullable = true)
#  |-- eeg68: double (nullable = true)
#  |-- eeg69: double (nullable = true)
#  |-- eeg70: double (nullable = true)
#  |-- eeg71: double (nullable = true)
#  |-- eeg72: double (nullable = true)
#  |-- eeg73: double (nullable = true)
#  |-- eeg74: double (nullable = true)
#  |-- eeg75: double (nullable = true)
#  |-- eeg76: double (nullable = true)
#  |-- eeg77: double (nullable = true)
#  |-- eeg78: double (nullable = true)
#  |-- eeg79: double (nullable = true)
#  |-- eeg80: double (nullable = true)
#  |-- eeg81: double (nullable = true)
#  |-- eeg82: double (nullable = true)
#  |-- eeg83: double (nullable = true)
#  |-- eeg84: double (nullable = true)
#  |-- eeg85: double (nullable = true)
#  |-- eeg86: double (nullable = true)
#  |-- eeg87: double (nullable = true)
#  |-- eeg88: double (nullable = true)
#  |-- eeg89: double (nullable = true)
#  |-- eeg90: double (nullable = true)
#  |-- eeg91: double (nullable = true)
#  |-- eeg92: double (nullable = true)
#  |-- eeg93: double (nullable = true)
#  |-- eeg94: double (nullable = true)
#  |-- eeg95: double (nullable = true)
#  |-- eeg96: double (nullable = true)
#  |-- eeg97: double (nullable = true)
#  |-- eeg98: double (nullable = true)
#  |-- eeg99: double (nullable = true)
#  |-- eeg100: double (nullable = true)
#  |-- eeg101: double (nullable = true)
#  |-- eeg102: double (nullable = true)
#  |-- eeg103: double (nullable = true)
#  |-- eeg104: double (nullable = true)
#  |-- eeg105: double (nullable = true)
#  |-- eeg106: double (nullable = true)
#  |-- eeg107: double (nullable = true)
#  |-- eeg108: double (nullable = true)
#  |-- eeg109: double (nullable = true)
#  |-- eeg110: double (nullable = true)
#  |-- eeg111: double (nullable = true)
#  |-- eeg112: double (nullable = true)
#  |-- eeg113: double (nullable = true)
#  |-- eeg114: double (nullable = true)
#  |-- eeg115: double (nullable = true)
#  |-- eeg116: double (nullable = true)
#  |-- eeg117: double (nullable = true)
#  |-- eeg118: double (nullable = true)
#  |-- eeg119: double (nullable = true)
#  |-- eeg120: double (nullable = true)
#  |-- eeg121: double (nullable = true)
#  |-- eeg122: double (nullable = true)
#  |-- eeg123: double (nullable = true)
#  |-- eeg124: double (nullable = true)
#  |-- eeg125: double (nullable = true)
#  |-- eeg126: double (nullable = true)
#  |-- eeg127: double (nullable = true)
#  |-- eeg128: double (nullable = true)
#  |-- eeg129: double (nullable = true)
#  |-- eeg130: double (nullable = true)
#  |-- eeg131: double (nullable = true)
#  |-- eeg132: double (nullable = true)
#  |-- eeg133: double (nullable = true)
#  |-- eeg134: double (nullable = true)
#  |-- eeg135: double (nullable = true)
#  |-- eeg136: double (nullable = true)
#  |-- eeg137: double (nullable = true)
#  |-- eeg138: double (nullable = true)
#  |-- eeg139: double (nullable = true)
#  |-- eeg140: double (nullable = true)
#  |-- eeg141: double (nullable = true)
#  |-- eeg142: double (nullable = true)
#  |-- eeg143: double (nullable = true)
#  |-- eeg144: double (nullable = true)
#  |-- eeg145: double (nullable = true)
#  |-- eeg146: double (nullable = true)
#  |-- eeg147: double (nullable = true)
#  |-- eeg148: double (nullable = true)
#  |-- eeg149: double (nullable = true)
#  |-- eeg150: double (nullable = true)
#  |-- eeg151: double (nullable = true)
#  |-- eeg152: double (nullable = true)
#  |-- eeg153: double (nullable = true)
#  |-- eeg154: double (nullable = true)
#  |-- eeg155: double (nullable = true)
#  |-- eeg156: double (nullable = true)
#  |-- eeg157: double (nullable = true)
#  |-- eeg158: double (nullable = true)
#  |-- eeg159: double (nullable = true)
#  |-- eeg160: double (nullable = true)
#  |-- eeg161: double (nullable = true)
#  |-- eeg162: double (nullable = true)
#  |-- eeg163: double (nullable = true)
#  |-- eeg164: double (nullable = true)
#  |-- eeg165: double (nullable = true)
#  |-- eeg166: double (nullable = true)
#  |-- eeg167: double (nullable = true)
#  |-- eeg168: double (nullable = true)
#  |-- eeg169: double (nullable = true)
#  |-- eeg170: double (nullable = true)
#  |-- eeg171: double (nullable = true)
#  |-- eeg172: double (nullable = true)
#  |-- eeg173: double (nullable = true)
#  |-- eeg174: double (nullable = true)
#  |-- eeg175: double (nullable = true)
#  |-- eeg176: double (nullable = true)
#  |-- eeg177: double (nullable = true)
#  |-- eeg178: double (nullable = true)
#  |-- eeg179: double (nullable = true)
#  |-- eeg180: double (nullable = true)
#  |-- eeg181: double (nullable = true)
#  |-- eeg182: double (nullable = true)
#  |-- eeg183: double (nullable = true)
#  |-- eeg184: double (nullable = true)
#  |-- eeg185: double (nullable = true)
#  |-- eeg186: double (nullable = true)
#  |-- eeg187: double (nullable = true)
#  |-- eeg188: double (nullable = true)
#  |-- eeg189: double (nullable = true)
#  |-- eeg190: double (nullable = true)
#  |-- eeg191: double (nullable = true)
#  |-- eeg192: double (nullable = true)
#  |-- eeg193: double (nullable = true)
#  |-- eeg194: double (nullable = true)
#  |-- eeg195: double (nullable = true)
#  |-- eeg196: double (nullable = true)
#  |-- eeg197: double (nullable = true)
#  |-- eeg198: double (nullable = true)
#  |-- eeg199: double (nullable = true)
#  |-- eeg200: double (nullable = true)
#  |-- eeg201: double (nullable = true)
#  |-- eeg202: double (nullable = true)
#  |-- eeg203: double (nullable = true)
#  |-- eeg204: double (nullable = true)
#  |-- eeg205: double (nullable = true)
#  |-- eeg206: double (nullable = true)
#  |-- eeg207: double (nullable = true)
#  |-- eeg208: double (nullable = true)
#  |-- eeg209: double (nullable = true)
#  |-- eeg210: double (nullable = true)
#  |-- eeg211: double (nullable = true)
#  |-- eeg212: double (nullable = true)
#  |-- eeg213: double (nullable = true)
#  |-- eeg214: double (nullable = true)
#  |-- eeg215: double (nullable = true)
#  |-- eeg216: double (nullable = true)
#  |-- eeg217: double (nullable = true)
#  |-- eeg218: double (nullable = true)
#  |-- eeg219: double (nullable = true)
#  |-- eeg220: double (nullable = true)
#  |-- eeg221: double (nullable = true)
#  |-- eeg222: double (nullable = true)
#  |-- eeg223: double (nullable = true)
#  |-- eeg224: double (nullable = true)
#  |-- eeg225: double (nullable = true)
#  |-- eeg226: double (nullable = true)
#  |-- eeg227: double (nullable = true)
#  |-- eeg228: double (nullable = true)
#  |-- eeg229: double (nullable = true)
#  |-- eeg230: double (nullable = true)
#  |-- eeg231: double (nullable = true)
#  |-- eeg232: double (nullable = true)
#  |-- eeg233: double (nullable = true)
#  |-- eeg234: double (nullable = true)
#  |-- eeg235: double (nullable = true)
#  |-- eeg236: double (nullable = true)
#  |-- eeg237: double (nullable = true)
#  |-- eeg238: double (nullable = true)
#  |-- eeg239: double (nullable = true)
#  |-- eeg240: double (nullable = true)
#  |-- eeg241: double (nullable = true)
#  |-- eeg242: double (nullable = true)
#  |-- eeg243: double (nullable = true)
#  |-- eeg244: double (nullable = true)
#  |-- eeg245: double (nullable = true)
#  |-- eeg246: double (nullable = true)
#  |-- eeg247: double (nullable = true)
#  |-- eeg248: double (nullable = true)
#  |-- eeg249: double (nullable = true)
#  |-- eeg250: double (nullable = true)
#  |-- eeg251: double (nullable = true)
#  |-- eeg252: double (nullable = true)
#  |-- eeg253: double (nullable = true)
#  |-- eeg254: double (nullable = true)
#  |-- eeg255: double (nullable = true)
#  |-- eeg256: double (nullable = true)
#  |-- eeg257: double (nullable = true)
#  |-- eeg258: double (nullable = true)
#  |-- eeg259: double (nullable = true)
#  |-- eeg260: double (nullable = true)
#  |-- eeg261: double (nullable = true)
#  |-- eeg262: double (nullable = true)
#  |-- eeg263: double (nullable = true)
#  |-- eeg264: double (nullable = true)
#  |-- eeg265: double (nullable = true)
#  |-- eeg266: double (nullable = true)
#  |-- eeg267: double (nullable = true)
#  |-- eeg268: double (nullable = true)
#  |-- eeg269: double (nullable = true)
#  |-- eeg270: double (nullable = true)
#  |-- eeg271: double (nullable = true)
#  |-- eeg272: double (nullable = true)
#  |-- eeg273: double (nullable = true)
#  |-- eeg274: double (nullable = true)
#  |-- eeg275: double (nullable = true)
#  |-- eeg276: double (nullable = true)
#  |-- eeg277: double (nullable = true)
#  |-- eeg278: double (nullable = true)
#  |-- eeg279: double (nullable = true)
#  |-- eeg280: double (nullable = true)
#  |-- eeg281: double (nullable = true)
#  |-- eeg282: double (nullable = true)
#  |-- eeg283: double (nullable = true)
#  |-- eeg284: double (nullable = true)
#  |-- eeg285: double (nullable = true)
#  |-- eeg286: double (nullable = true)
#  |-- eeg287: double (nullable = true)
#  |-- eeg288: double (nullable = true)
#  |-- eeg289: double (nullable = true)
#  |-- eeg290: double (nullable = true)
#  |-- eeg291: double (nullable = true)
#  |-- eeg292: double (nullable = true)
#  |-- eeg293: double (nullable = true)
#  |-- eeg294: double (nullable = true)
#  |-- eeg295: double (nullable = true)
#  |-- eeg296: double (nullable = true)
#  |-- eeg297: double (nullable = true)
#  |-- eeg298: double (nullable = true)
#  |-- eeg299: double (nullable = true)
#  |-- eeg300: double (nullable = true)
#  |-- eeg301: double (nullable = true)
#  |-- eeg302: double (nullable = true)
#  |-- eeg303: double (nullable = true)
#  |-- eeg304: double (nullable = true)
#  |-- eeg305: double (nullable = true)
#  |-- eeg306: double (nullable = true)
#  |-- eeg307: double (nullable = true)
#  |-- eeg308: double (nullable = true)
#  |-- eeg309: double (nullable = true)
#  |-- eeg310: double (nullable = true)
#  |-- eeg311: double (nullable = true)
#  |-- eeg312: double (nullable = true)
#  |-- eeg313: double (nullable = true)
#  |-- eeg314: double (nullable = true)
#  |-- eeg315: double (nullable = true)
#  |-- eeg316: double (nullable = true)
#  |-- eeg317: double (nullable = true)
#  |-- eeg318: double (nullable = true)
#  |-- eeg319: double (nullable = true)
#  |-- eeg320: double (nullable = true)
#  |-- eeg321: double (nullable = true)
#  |-- eeg322: double (nullable = true)
#  |-- eeg323: double (nullable = true)
#  |-- eeg324: double (nullable = true)
#  |-- eeg325: double (nullable = true)
#  |-- eeg326: double (nullable = true)
#  |-- eeg327: double (nullable = true)
#  |-- eeg328: double (nullable = true)
#  |-- eeg329: double (nullable = true)
#  |-- eeg330: double (nullable = true)
#  |-- eeg331: double (nullable = true)
#  |-- eeg332: double (nullable = true)
#  |-- eeg333: double (nullable = true)
#  |-- eeg334: double (nullable = true)
#  |-- eeg335: double (nullable = true)
#  |-- eeg336: double (nullable = true)
#  |-- eeg337: double (nullable = true)
#  |-- eeg338: double (nullable = true)
#  |-- eeg339: double (nullable = true)
#  |-- eeg340: double (nullable = true)
#  |-- eeg341: double (nullable = true)
#  |-- eeg342: double (nullable = true)
#  |-- eeg343: double (nullable = true)
#  |-- eeg344: double (nullable = true)
#  |-- eeg345: double (nullable = true)
#  |-- eeg346: double (nullable = true)
#  |-- eeg347: double (nullable = true)
#  |-- eeg348: double (nullable = true)
#  |-- eeg349: double (nullable = true)
#  |-- eeg350: double (nullable = true)
#  |-- eeg351: double (nullable = true)
#  |-- eeg352: double (nullable = true)
#  |-- eeg353: double (nullable = true)
#  |-- eeg354: double (nullable = true)
#  |-- eeg355: double (nullable = true)
#  |-- eeg356: double (nullable = true)
#  |-- eeg357: double (nullable = true)
#  |-- eeg358: double (nullable = true)
#  |-- eeg359: double (nullable = true)
#  |-- eeg360: double (nullable = true)
#  |-- eeg361: double (nullable = true)
#  |-- eeg362: double (nullable = true)
#  |-- eeg363: double (nullable = true)
#  |-- eeg364: double (nullable = true)
#  |-- eeg365: double (nullable = true)
#  |-- eeg366: double (nullable = true)
#  |-- eeg367: double (nullable = true)
#  |-- eeg368: double (nullable = true)
#  |-- eeg369: double (nullable = true)
#  |-- eeg370: double (nullable = true)
#  |-- eeg371: double (nullable = true)
#  |-- eeg372: double (nullable = true)
#  |-- eeg373: double (nullable = true)
#  |-- eeg374: double (nullable = true)
#  |-- eeg375: double (nullable = true)
#  |-- eeg376: double (nullable = true)
#  |-- eeg377: double (nullable = true)
#  |-- eeg378: double (nullable = true)
#  |-- eeg379: double (nullable = true)
#  |-- eeg380: double (nullable = true)
#  |-- eeg381: double (nullable = true)
#  |-- eeg382: double (nullable = true)
#  |-- eeg383: double (nullable = true)
#  |-- eeg384: double (nullable = true)
#  |-- eeg385: double (nullable = true)
#  |-- eeg386: double (nullable = true)
#  |-- eeg387: double (nullable = true)
#  |-- eeg388: double (nullable = true)
#  |-- eeg389: double (nullable = true)
#  |-- eeg390: double (nullable = true)
#  |-- eeg391: double (nullable = true)
#  |-- eeg392: double (nullable = true)
#  |-- eeg393: double (nullable = true)
#  |-- eeg394: double (nullable = true)
#  |-- eeg395: double (nullable = true)
#  |-- eeg396: double (nullable = true)
#  |-- eeg397: double (nullable = true)
#  |-- eeg398: double (nullable = true)
#  |-- eeg399: double (nullable = true)
#  |-- eeg400: double (nullable = true)
#  |-- eeg401: double (nullable = true)
#  |-- eeg402: double (nullable = true)
#  |-- eeg403: double (nullable = true)
#  |-- eeg404: double (nullable = true)
#  |-- eeg405: double (nullable = true)
#  |-- eeg406: double (nullable = true)
#  |-- eeg407: double (nullable = true)
#  |-- eeg408: double (nullable = true)
#  |-- eeg409: double (nullable = true)
#  |-- eeg410: double (nullable = true)
#  |-- eeg411: double (nullable = true)
#  |-- eeg412: double (nullable = true)
#  |-- eeg413: double (nullable = true)
#  |-- eeg414: double (nullable = true)
#  |-- eeg415: double (nullable = true)
#  |-- eeg416: double (nullable = true)
#  |-- eeg417: double (nullable = true)
#  |-- eeg418: double (nullable = true)
#  |-- eeg419: double (nullable = true)
#  |-- eeg420: double (nullable = true)
#  |-- eeg421: double (nullable = true)
#  |-- eeg422: double (nullable = true)
#  |-- eeg423: double (nullable = true)
#  |-- eeg424: double (nullable = true)
#  |-- eeg425: double (nullable = true)
#  |-- eeg426: double (nullable = true)
#  |-- eeg427: double (nullable = true)
#  |-- eeg428: double (nullable = true)
#  |-- eeg429: double (nullable = true)
#  |-- eeg430: double (nullable = true)
#  |-- eeg431: double (nullable = true)
#  |-- eeg432: double (nullable = true)
#  |-- eeg433: double (nullable = true)
#  |-- eeg434: double (nullable = true)
#  |-- eeg435: double (nullable = true)
#  |-- eeg436: double (nullable = true)
#  |-- eeg437: double (nullable = true)
#  |-- eeg438: double (nullable = true)
#  |-- eeg439: double (nullable = true)
#  |-- eeg440: double (nullable = true)
#  |-- eeg441: double (nullable = true)
#  |-- eeg442: double (nullable = true)
#  |-- eeg443: double (nullable = true)
#  |-- eeg444: double (nullable = true)
#  |-- eeg445: double (nullable = true)
#  |-- eeg446: double (nullable = true)
#  |-- eeg447: double (nullable = true)
#  |-- eeg448: double (nullable = true)
#  |-- eeg449: double (nullable = true)
#  |-- eeg450: double (nullable = true)
#  |-- eeg451: double (nullable = true)
#  |-- eeg452: double (nullable = true)
#  |-- eeg453: double (nullable = true)
#  |-- eeg454: double (nullable = true)
#  |-- eeg455: double (nullable = true)
#  |-- eeg456: double (nullable = true)
#  |-- eeg457: double (nullable = true)
#  |-- eeg458: double (nullable = true)
#  |-- eeg459: double (nullable = true)
#  |-- eeg460: double (nullable = true)
#  |-- eeg461: double (nullable = true)
#  |-- eeg462: double (nullable = true)
#  |-- eeg463: double (nullable = true)
#  |-- eeg464: double (nullable = true)
#  |-- eeg465: double (nullable = true)
#  |-- eeg466: double (nullable = true)
#  |-- eeg467: double (nullable = true)
#  |-- eeg468: double (nullable = true)
#  |-- eeg469: double (nullable = true)
#  |-- eeg470: double (nullable = true)
#  |-- eeg471: double (nullable = true)
#  |-- eeg472: double (nullable = true)
#  |-- eeg473: double (nullable = true)
#  |-- eeg474: double (nullable = true)
#  |-- eeg475: double (nullable = true)
#  |-- eeg476: double (nullable = true)
#  |-- eeg477: double (nullable = true)
#  |-- eeg478: double (nullable = true)
#  |-- eeg479: double (nullable = true)
#  |-- eeg480: double (nullable = true)
#  |-- eeg481: double (nullable = true)
#  |-- eeg482: double (nullable = true)
#  |-- eeg483: double (nullable = true)
#  |-- eeg484: double (nullable = true)
#  |-- eeg485: double (nullable = true)
#  |-- eeg486: double (nullable = true)
#  |-- eeg487: double (nullable = true)
#  |-- eeg488: double (nullable = true)
#  |-- eeg489: double (nullable = true)
#  |-- eeg490: double (nullable = true)
#  |-- eeg491: double (nullable = true)
#  |-- eeg492: double (nullable = true)
#  |-- eeg493: double (nullable = true)
#  |-- eeg494: double (nullable = true)
#  |-- eeg495: double (nullable = true)
#  |-- eeg496: double (nullable = true)
#  |-- eeg497: double (nullable = true)
#  |-- eeg498: double (nullable = true)
#  |-- eeg499: double (nullable = true)
#  |-- eeg500: double (nullable = true)
#  |-- eeg501: double (nullable = true)
#  |-- eeg502: double (nullable = true)
#  |-- eeg503: double (nullable = true)
#  |-- eeg504: double (nullable = true)
#  |-- eeg505: double (nullable = true)
#  |-- eeg506: double (nullable = true)
#  |-- eeg507: double (nullable = true)
#  |-- eeg508: double (nullable = true)
#  |-- eeg509: double (nullable = true)
#  |-- eeg510: double (nullable = true)
#  |-- eeg511: double (nullable = true)
#  |-- eeg512: double (nullable = true)
#  |-- eeg513: double (nullable = true)
#  |-- eeg514: double (nullable = true)
#  |-- eeg515: double (nullable = true)
#  |-- eeg516: double (nullable = true)
#  |-- eeg517: double (nullable = true)
#  |-- eeg518: double (nullable = true)
#  |-- eeg519: double (nullable = true)
#  |-- eeg520: double (nullable = true)
#  |-- eeg521: double (nullable = true)
#  |-- eeg522: double (nullable = true)
#  |-- eeg523: double (nullable = true)
#  |-- eeg524: double (nullable = true)
#  |-- eeg525: double (nullable = true)
#  |-- eeg526: double (nullable = true)
#  |-- eeg527: double (nullable = true)
#  |-- eeg528: double (nullable = true)
#  |-- eeg529: double (nullable = true)
#  |-- eeg530: double (nullable = true)
#  |-- eeg531: double (nullable = true)
#  |-- eeg532: double (nullable = true)
#  |-- eeg533: double (nullable = true)
#  |-- eeg534: double (nullable = true)
#  |-- eeg535: double (nullable = true)
#  |-- eeg536: double (nullable = true)
#  |-- eeg537: double (nullable = true)
#  |-- eeg538: double (nullable = true)
#  |-- eeg539: double (nullable = true)
#  |-- eeg540: double (nullable = true)
#  |-- eeg541: double (nullable = true)
#  |-- eeg542: double (nullable = true)
#  |-- eeg543: double (nullable = true)
#  |-- eeg544: double (nullable = true)
#  |-- eeg545: double (nullable = true)
#  |-- eeg546: double (nullable = true)
#  |-- eeg547: double (nullable = true)
#  |-- eeg548: double (nullable = true)
#  |-- eeg549: double (nullable = true)
#  |-- eeg550: double (nullable = true)
#  |-- eeg551: double (nullable = true)
#  |-- eeg552: double (nullable = true)
#  |-- eeg553: double (nullable = true)
#  |-- eeg554: double (nullable = true)
#  |-- eeg555: double (nullable = true)
#  |-- eeg556: double (nullable = true)
#  |-- eeg557: double (nullable = true)
#  |-- eeg558: double (nullable = true)
#  |-- eeg559: double (nullable = true)
#  |-- eeg560: double (nullable = true)
#  |-- eeg561: double (nullable = true)
#  |-- eeg562: double (nullable = true)
#  |-- eeg563: double (nullable = true)
#  |-- eeg564: double (nullable = true)
#  |-- eeg565: double (nullable = true)
#  |-- eeg566: double (nullable = true)
#  |-- eeg567: double (nullable = true)
#  |-- eeg568: double (nullable = true)
#  |-- eeg569: double (nullable = true)
#  |-- eeg570: double (nullable = true)
#  |-- eeg571: double (nullable = true)
#  |-- eeg572: double (nullable = true)
#  |-- eeg573: double (nullable = true)
#  |-- eeg574: double (nullable = true)
#  |-- eeg575: double (nullable = true)
#  |-- eeg576: double (nullable = true)
#  |-- eeg577: double (nullable = true)
#  |-- eeg578: double (nullable = true)
#  |-- eeg579: double (nullable = true)
#  |-- eeg580: double (nullable = true)
#  |-- eeg581: double (nullable = true)
#  |-- eeg582: double (nullable = true)
#  |-- eeg583: double (nullable = true)
#  |-- eeg584: double (nullable = true)
#  |-- eeg585: double (nullable = true)
#  |-- eeg586: double (nullable = true)
#  |-- eeg587: double (nullable = true)
#  |-- eeg588: double (nullable = true)
#  |-- eeg589: double (nullable = true)
#  |-- eeg590: double (nullable = true)
#  |-- eeg591: double (nullable = true)
#  |-- eeg592: double (nullable = true)
#  |-- eeg593: double (nullable = true)
#  |-- eeg594: double (nullable = true)
#  |-- eeg595: double (nullable = true)
#  |-- eeg596: double (nullable = true)
#  |-- eeg597: double (nullable = true)
#  |-- eeg598: double (nullable = true)
#  |-- eeg599: double (nullable = true)
#  |-- eeg600: double (nullable = true)
#  |-- eeg601: double (nullable = true)
#  |-- eeg602: double (nullable = true)
#  |-- eeg603: double (nullable = true)
#  |-- eeg604: double (nullable = true)
#  |-- eeg605: double (nullable = true)
#  |-- eeg606: double (nullable = true)
#  |-- eeg607: double (nullable = true)
#  |-- eeg608: double (nullable = true)
#  |-- eeg609: double (nullable = true)
#  |-- eeg610: double (nullable = true)
#  |-- eeg611: double (nullable = true)
#  |-- eeg612: double (nullable = true)
#  |-- eeg613: double (nullable = true)
#  |-- eeg614: double (nullable = true)
#  |-- eeg615: double (nullable = true)
#  |-- eeg616: double (nullable = true)
#  |-- eeg617: double (nullable = true)
#  |-- eeg618: double (nullable = true)
#  |-- eeg619: double (nullable = true)
#  |-- eeg620: double (nullable = true)
#  |-- eeg621: double (nullable = true)
#  |-- eeg622: double (nullable = true)
#  |-- eeg623: double (nullable = true)
#  |-- eeg624: double (nullable = true)
#  |-- eeg625: double (nullable = true)
#  |-- eeg626: double (nullable = true)
#  |-- eeg627: double (nullable = true)
#  |-- eeg628: double (nullable = true)
#  |-- eeg629: double (nullable = true)
#  |-- eeg630: double (nullable = true)
#  |-- eeg631: double (nullable = true)
#  |-- eeg632: double (nullable = true)
#  |-- eeg633: double (nullable = true)
#  |-- eeg634: double (nullable = true)
#  |-- eeg635: double (nullable = true)
#  |-- eeg636: double (nullable = true)
#  |-- eeg637: double (nullable = true)
#  |-- eeg638: double (nullable = true)
#  |-- eeg639: double (nullable = true)
#  |-- eeg640: double (nullable = true)
#  |-- eeg641: double (nullable = true)
#  |-- eeg642: double (nullable = true)
#  |-- eeg643: double (nullable = true)
#  |-- eeg644: double (nullable = true)
#  |-- eeg645: double (nullable = true)
#  |-- eeg646: double (nullable = true)
#  |-- eeg647: double (nullable = true)
#  |-- eeg648: double (nullable = true)
#  |-- eeg649: double (nullable = true)
#  |-- eeg650: double (nullable = true)
#  |-- eeg651: double (nullable = true)
#  |-- eeg652: double (nullable = true)
#  |-- eeg653: double (nullable = true)
#  |-- eeg654: double (nullable = true)
#  |-- eeg655: double (nullable = true)
#  |-- eeg656: double (nullable = true)
#  |-- eeg657: double (nullable = true)
#  |-- eeg658: double (nullable = true)
#  |-- eeg659: double (nullable = true)
#  |-- eeg660: double (nullable = true)
#  |-- eeg661: double (nullable = true)
#  |-- eeg662: double (nullable = true)
#  |-- eeg663: double (nullable = true)
#  |-- eeg664: double (nullable = true)
#  |-- eeg665: double (nullable = true)
#  |-- eeg666: double (nullable = true)
#  |-- eeg667: double (nullable = true)
#  |-- eeg668: double (nullable = true)
#  |-- eeg669: double (nullable = true)
#  |-- eeg670: double (nullable = true)
#  |-- eeg671: double (nullable = true)
#  |-- eeg672: double (nullable = true)
#  |-- eeg673: double (nullable = true)
#  |-- eeg674: double (nullable = true)
#  |-- eeg675: double (nullable = true)
#  |-- eeg676: double (nullable = true)
#  |-- eeg677: double (nullable = true)
#  |-- eeg678: double (nullable = true)
#  |-- eeg679: double (nullable = true)
#  |-- eeg680: double (nullable = true)
#  |-- eeg681: double (nullable = true)
#  |-- eeg682: double (nullable = true)
#  |-- eeg683: double (nullable = true)
#  |-- eeg684: double (nullable = true)
#  |-- eeg685: double (nullable = true)
#  |-- eeg686: double (nullable = true)
#  |-- eeg687: double (nullable = true)
#  |-- eeg688: double (nullable = true)
#  |-- eeg689: double (nullable = true)
#  |-- eeg690: double (nullable = true)
#  |-- eeg691: double (nullable = true)
#  |-- eeg692: double (nullable = true)
#  |-- eeg693: double (nullable = true)
#  |-- eeg694: double (nullable = true)
#  |-- eeg695: double (nullable = true)
#  |-- eeg696: double (nullable = true)
#  |-- eeg697: double (nullable = true)
#  |-- eeg698: double (nullable = true)
#  |-- eeg699: double (nullable = true)
#  |-- eeg700: double (nullable = true)
#  |-- eeg701: double (nullable = true)
#  |-- eeg702: double (nullable = true)
#  |-- eeg703: double (nullable = true)
#  |-- eeg704: double (nullable = true)
#  |-- eeg705: double (nullable = true)
#  |-- eeg706: double (nullable = true)
#  |-- eeg707: double (nullable = true)
#  |-- eeg708: double (nullable = true)
#  |-- eeg709: double (nullable = true)
#  |-- eeg710: double (nullable = true)
#  |-- eeg711: double (nullable = true)
#  |-- eeg712: double (nullable = true)
#  |-- eeg713: double (nullable = true)
#  |-- eeg714: double (nullable = true)
#  |-- eeg715: double (nullable = true)
#  |-- eeg716: double (nullable = true)
#  |-- eeg717: double (nullable = true)
#  |-- eeg718: double (nullable = true)
#  |-- eeg719: double (nullable = true)
#  |-- eeg720: double (nullable = true)
#  |-- eeg721: double (nullable = true)
#  |-- eeg722: double (nullable = true)
#  |-- eeg723: double (nullable = true)
#  |-- eeg724: double (nullable = true)
#  |-- eeg725: double (nullable = true)
#  |-- eeg726: double (nullable = true)
#  |-- eeg727: double (nullable = true)
#  |-- eeg728: double (nullable = true)
#  |-- eeg729: double (nullable = true)
#  |-- eeg730: double (nullable = true)
#  |-- eeg731: double (nullable = true)
#  |-- eeg732: double (nullable = true)
#  |-- eeg733: double (nullable = true)
#  |-- eeg734: double (nullable = true)
#  |-- eeg735: double (nullable = true)
#  |-- eeg736: double (nullable = true)
#  |-- eeg737: double (nullable = true)
#  |-- eeg738: double (nullable = true)
#  |-- eeg739: double (nullable = true)
#  |-- eeg740: double (nullable = true)
#  |-- eeg741: double (nullable = true)
#  |-- eeg742: double (nullable = true)
#  |-- eeg743: double (nullable = true)
#  |-- eeg744: double (nullable = true)
#  |-- eeg745: double (nullable = true)
#  |-- eeg746: double (nullable = true)
#  |-- eeg747: double (nullable = true)
#  |-- eeg748: double (nullable = true)
#  |-- eeg749: double (nullable = true)
#  |-- eeg750: double (nullable = true)
#  |-- eeg751: double (nullable = true)
#  |-- eeg752: double (nullable = true)
#  |-- eeg753: double (nullable = true)
#  |-- eeg754: double (nullable = true)
#  |-- eeg755: double (nullable = true)
#  |-- eeg756: double (nullable = true)
#  |-- eeg757: double (nullable = true)
#  |-- eeg758: double (nullable = true)
#  |-- eeg759: double (nullable = true)
#  |-- eeg760: double (nullable = true)
#  |-- eeg761: double (nullable = true)
#  |-- eeg762: double (nullable = true)
#  |-- eeg763: double (nullable = true)
#  |-- eeg764: double (nullable = true)
#  |-- eeg765: double (nullable = true)
#  |-- eeg766: double (nullable = true)
#  |-- eeg767: double (nullable = true)
#  |-- eeg768: double (nullable = true)
#  |-- eeg769: double (nullable = true)
#  |-- eeg770: double (nullable = true)
#  |-- eeg771: double (nullable = true)
#  |-- eeg772: double (nullable = true)
#  |-- eeg773: double (nullable = true)
#  |-- eeg774: double (nullable = true)
#  |-- eeg775: double (nullable = true)
#  |-- eeg776: double (nullable = true)
#  |-- eeg777: double (nullable = true)
#  |-- eeg778: double (nullable = true)
#  |-- eeg779: double (nullable = true)
#  |-- eeg780: double (nullable = true)
#  |-- eeg781: double (nullable = true)
#  |-- eeg782: double (nullable = true)
#  |-- eeg783: double (nullable = true)
#  |-- eeg784: double (nullable = true)
#  |-- eeg785: double (nullable = true)
#  |-- eeg786: double (nullable = true)
#  |-- eeg787: double (nullable = true)
#  |-- eeg788: double (nullable = true)
#  |-- eeg789: double (nullable = true)
#  |-- eeg790: double (nullable = true)
#  |-- eeg791: double (nullable = true)
#  |-- eeg792: double (nullable = true)
#  |-- eeg793: double (nullable = true)
#  |-- eeg794: double (nullable = true)
#  |-- eeg795: double (nullable = true)
#  |-- eeg796: double (nullable = true)
#  |-- eeg797: double (nullable = true)
#  |-- eeg798: double (nullable = true)
#  |-- eeg799: double (nullable = true)
#  |-- eeg800: double (nullable = true)
#  |-- eeg801: double (nullable = true)
#  |-- eeg802: double (nullable = true)
#  |-- eeg803: double (nullable = true)
#  |-- eeg804: double (nullable = true)
#  |-- eeg805: double (nullable = true)
#  |-- eeg806: double (nullable = true)
#  |-- eeg807: double (nullable = true)
#  |-- eeg808: double (nullable = true)
#  |-- eeg809: double (nullable = true)
#  |-- eeg810: double (nullable = true)
#  |-- eeg811: double (nullable = true)
#  |-- eeg812: double (nullable = true)
#  |-- eeg813: double (nullable = true)
#  |-- eeg814: double (nullable = true)
#  |-- eeg815: double (nullable = true)
#  |-- eeg816: double (nullable = true)
#  |-- eeg817: double (nullable = true)
#  |-- eeg818: double (nullable = true)
#  |-- eeg819: double (nullable = true)
#  |-- eeg820: double (nullable = true)
#  |-- eeg821: double (nullable = true)
#  |-- eeg822: double (nullable = true)
#  |-- eeg823: double (nullable = true)
#  |-- eeg824: double (nullable = true)
#  |-- eeg825: double (nullable = true)
#  |-- eeg826: double (nullable = true)
#  |-- eeg827: double (nullable = true)
#  |-- eeg828: double (nullable = true)
#  |-- eeg829: double (nullable = true)
#  |-- eeg830: double (nullable = true)
#  |-- eeg831: double (nullable = true)
#  |-- eeg832: double (nullable = true)
#  |-- eeg833: double (nullable = true)
#  |-- eeg834: double (nullable = true)
#  |-- eeg835: double (nullable = true)
#  |-- eeg836: double (nullable = true)
#  |-- eeg837: double (nullable = true)
#  |-- eeg838: double (nullable = true)
#  |-- eeg839: double (nullable = true)
#  |-- eeg840: double (nullable = true)
#  |-- eeg841: double (nullable = true)
#  |-- eeg842: double (nullable = true)
#  |-- eeg843: double (nullable = true)
#  |-- eeg844: double (nullable = true)
#  |-- eeg845: double (nullable = true)
#  |-- eeg846: double (nullable = true)
#  |-- eeg847: double (nullable = true)
#  |-- eeg848: double (nullable = true)
#  |-- eeg849: double (nullable = true)
#  |-- eeg850: double (nullable = true)
#  |-- eeg851: double (nullable = true)
#  |-- eeg852: double (nullable = true)
#  |-- eeg853: double (nullable = true)
#  |-- eeg854: double (nullable = true)
#  |-- eeg855: double (nullable = true)
#  |-- eeg856: double (nullable = true)
#  |-- eeg857: double (nullable = true)
#  |-- eeg858: double (nullable = true)
#  |-- eeg859: double (nullable = true)
#  |-- eeg860: double (nullable = true)
#  |-- eeg861: double (nullable = true)
#  |-- eeg862: double (nullable = true)
#  |-- eeg863: double (nullable = true)
#  |-- eeg864: double (nullable = true)
#  |-- eeg865: double (nullable = true)
#  |-- eeg866: double (nullable = true)
#  |-- eeg867: double (nullable = true)
#  |-- eeg868: double (nullable = true)
#  |-- eeg869: double (nullable = true)
#  |-- eeg870: double (nullable = true)
#  |-- eeg871: double (nullable = true)
#  |-- eeg872: double (nullable = true)
#  |-- eeg873: double (nullable = true)
#  |-- eeg874: double (nullable = true)
#  |-- eeg875: double (nullable = true)
#  |-- eeg876: double (nullable = true)
#  |-- eeg877: double (nullable = true)
#  |-- eeg878: double (nullable = true)
#  |-- eeg879: double (nullable = true)
#  |-- eeg880: double (nullable = true)
#  |-- eeg881: double (nullable = true)
#  |-- eeg882: double (nullable = true)
#  |-- eeg883: double (nullable = true)
#  |-- eeg884: double (nullable = true)
#  |-- eeg885: double (nullable = true)
#  |-- eeg886: double (nullable = true)
#  |-- eeg887: double (nullable = true)
#  |-- eeg888: double (nullable = true)
#  |-- eeg889: double (nullable = true)
#  |-- eeg890: double (nullable = true)
#  |-- eeg891: double (nullable = true)
#  |-- eeg892: double (nullable = true)
#  |-- eeg893: double (nullable = true)
#  |-- eeg894: double (nullable = true)
#  |-- eeg895: double (nullable = true)
#  |-- eeg896: double (nullable = true)
#  |-- eeg897: double (nullable = true)
#  |-- eeg898: double (nullable = true)
#  |-- eeg899: double (nullable = true)
#  |-- eeg900: double (nullable = true)
#  |-- eeg901: double (nullable = true)
#  |-- eeg902: double (nullable = true)
#  |-- eeg903: double (nullable = true)
#  |-- eeg904: double (nullable = true)
#  |-- eeg905: double (nullable = true)
#  |-- eeg906: double (nullable = true)
#  |-- eeg907: double (nullable = true)
#  |-- eeg908: double (nullable = true)
#  |-- eeg909: double (nullable = true)
#  |-- eeg910: double (nullable = true)
#  |-- eeg911: double (nullable = true)
#  |-- eeg912: double (nullable = true)
#  |-- eeg913: double (nullable = true)
#  |-- eeg914: double (nullable = true)
#  |-- eeg915: double (nullable = true)
#  |-- eeg916: double (nullable = true)
#  |-- eeg917: double (nullable = true)
#  |-- eeg918: double (nullable = true)
#  |-- eeg919: double (nullable = true)
#  |-- eeg920: double (nullable = true)
#  |-- eeg921: double (nullable = true)
#  |-- eeg922: double (nullable = true)
#  |-- eeg923: double (nullable = true)
#  |-- eeg924: double (nullable = true)
#  |-- eeg925: double (nullable = true)
#  |-- eeg926: double (nullable = true)
#  |-- eeg927: double (nullable = true)
#  |-- eeg928: double (nullable = true)
#  |-- eeg929: double (nullable = true)
#  |-- eeg930: double (nullable = true)
#  |-- eeg931: double (nullable = true)
#  |-- eeg932: double (nullable = true)
#  |-- eeg933: double (nullable = true)
#  |-- eeg934: double (nullable = true)
#  |-- eeg935: double (nullable = true)
#  |-- eeg936: double (nullable = true)
#  |-- eeg937: double (nullable = true)
#  |-- eeg938: double (nullable = true)
#  |-- eeg939: double (nullable = true)
#  |-- eeg940: double (nullable = true)
#  |-- eeg941: double (nullable = true)
#  |-- eeg942: double (nullable = true)
#  |-- eeg943: double (nullable = true)
#  |-- eeg944: double (nullable = true)
#  |-- eeg945: double (nullable = true)
#  |-- eeg946: double (nullable = true)
#  |-- eeg947: double (nullable = true)
#  |-- eeg948: double (nullable = true)
#  |-- eeg949: double (nullable = true)
#  |-- eeg950: double (nullable = true)
#  |-- eeg951: double (nullable = true)
#  |-- eeg952: double (nullable = true)
#  |-- eeg953: double (nullable = true)
#  |-- eeg954: double (nullable = true)
#  |-- eeg955: double (nullable = true)
#  |-- eeg956: double (nullable = true)
#  |-- eeg957: double (nullable = true)
#  |-- eeg958: double (nullable = true)
#  |-- eeg959: double (nullable = true)
#  |-- eeg960: double (nullable = true)
#  |-- eeg961: double (nullable = true)
#  |-- eeg962: double (nullable = true)
#  |-- eeg963: double (nullable = true)
#  |-- eeg964: double (nullable = true)
#  |-- eeg965: double (nullable = true)
#  |-- eeg966: double (nullable = true)
#  |-- eeg967: double (nullable = true)
#  |-- eeg968: double (nullable = true)
#  |-- eeg969: double (nullable = true)
#  |-- eeg970: double (nullable = true)
#  |-- eeg971: double (nullable = true)
#  |-- eeg972: double (nullable = true)
#  |-- eeg973: double (nullable = true)
#  |-- eeg974: double (nullable = true)
#  |-- eeg975: double (nullable = true)
#  |-- eeg976: double (nullable = true)
#  |-- eeg977: double (nullable = true)
#  |-- eeg978: double (nullable = true)
#  |-- eeg979: double (nullable = true)
#  |-- eeg980: double (nullable = true)
#  |-- eeg981: double (nullable = true)
#  |-- eeg982: double (nullable = true)
#  |-- eeg983: double (nullable = true)
#  |-- eeg984: double (nullable = true)
#  |-- eeg985: double (nullable = true)
#  |-- eeg986: double (nullable = true)
#  |-- eeg987: double (nullable = true)
#  |-- eeg988: double (nullable = true)
#  |-- eeg989: double (nullable = true)
#  |-- eeg990: double (nullable = true)
#  |-- eeg991: double (nullable = true)
#  |-- eeg992: double (nullable = true)
#  |-- eeg993: double (nullable = true)
#  |-- eeg994: double (nullable = true)
#  |-- eeg995: double (nullable = true)
#  |-- eeg996: double (nullable = true)
#  |-- eeg997: double (nullable = true)
#  |-- eeg998: double (nullable = true)
#  |-- eeg999: double (nullable = true)
#  |-- eeg1000: double (nullable = true)
#  |-- eeg1001: double (nullable = true)
#  |-- eeg1002: double (nullable = true)
#  |-- eeg1003: double (nullable = true)
#  |-- eeg1004: double (nullable = true)
#  |-- eeg1005: double (nullable = true)
#  |-- eeg1006: double (nullable = true)
#  |-- eeg1007: double (nullable = true)
#  |-- eeg1008: double (nullable = true)
#  |-- eeg1009: double (nullable = true)
#  |-- eeg1010: double (nullable = true)
#  |-- eeg1011: double (nullable = true)
#  |-- eeg1012: double (nullable = true)
#  |-- eeg1013: double (nullable = true)
#  |-- eeg1014: double (nullable = true)
#  |-- eeg1015: double (nullable = true)
#  |-- eeg1016: double (nullable = true)
#  |-- eeg1017: double (nullable = true)
#  |-- eeg1018: double (nullable = true)
#  |-- eeg1019: double (nullable = true)
#  |-- eeg1020: double (nullable = true)
#  |-- eeg1021: double (nullable = true)
#  |-- eeg1022: double (nullable = true)
#  |-- eeg1023: double (nullable = true)
#  |-- eeg1024: double (nullable = true)
#  |-- eeg1025: double (nullable = true)
#  |-- eeg1026: double (nullable = true)
#  |-- eeg1027: double (nullable = true)
#  |-- eeg1028: double (nullable = true)
#  |-- eeg1029: double (nullable = true)
#  |-- eeg1030: double (nullable = true)
#  |-- eeg1031: double (nullable = true)
#  |-- eeg1032: double (nullable = true)
#  |-- eeg1033: double (nullable = true)
#  |-- eeg1034: double (nullable = true)
#  |-- eeg1035: double (nullable = true)
#  |-- eeg1036: double (nullable = true)
#  |-- eeg1037: double (nullable = true)
#  |-- eeg1038: double (nullable = true)
#  |-- eeg1039: double (nullable = true)
#  |-- eeg1040: double (nullable = true)
#  |-- eeg1041: double (nullable = true)
#  |-- eeg1042: double (nullable = true)
#  |-- eeg1043: double (nullable = true)
#  |-- eeg1044: double (nullable = true)
#  |-- eeg1045: double (nullable = true)
#  |-- eeg1046: double (nullable = true)
#  |-- eeg1047: double (nullable = true)
#  |-- eeg1048: double (nullable = true)
#  |-- eeg1049: double (nullable = true)
#  |-- eeg1050: double (nullable = true)
#  |-- eeg1051: double (nullable = true)
#  |-- eeg1052: double (nullable = true)
#  |-- eeg1053: double (nullable = true)
#  |-- eeg1054: double (nullable = true)
#  |-- eeg1055: double (nullable = true)
#  |-- eeg1056: double (nullable = true)
#  |-- eeg1057: double (nullable = true)
#  |-- eeg1058: double (nullable = true)
#  |-- eeg1059: double (nullable = true)
#  |-- eeg1060: double (nullable = true)
#  |-- eeg1061: double (nullable = true)
#  |-- eeg1062: double (nullable = true)
#  |-- eeg1063: double (nullable = true)
#  |-- eeg1064: double (nullable = true)
#  |-- eeg1065: double (nullable = true)
#  |-- eeg1066: double (nullable = true)
#  |-- eeg1067: double (nullable = true)
#  |-- eeg1068: double (nullable = true)
#  |-- eeg1069: double (nullable = true)
#  |-- eeg1070: double (nullable = true)
#  |-- eeg1071: double (nullable = true)
#  |-- eeg1072: double (nullable = true)
#  |-- eeg1073: double (nullable = true)
#  |-- eeg1074: double (nullable = true)
#  |-- eeg1075: double (nullable = true)
#  |-- eeg1076: double (nullable = true)
#  |-- eeg1077: double (nullable = true)
#  |-- eeg1078: double (nullable = true)
#  |-- eeg1079: double (nullable = true)
#  |-- eeg1080: double (nullable = true)
#  |-- eeg1081: double (nullable = true)
#  |-- eeg1082: double (nullable = true)
#  |-- eeg1083: double (nullable = true)
#  |-- eeg1084: double (nullable = true)
#  |-- eeg1085: double (nullable = true)
#  |-- eeg1086: double (nullable = true)
#  |-- eeg1087: double (nullable = true)
#  |-- eeg1088: double (nullable = true)
#  |-- eeg1089: double (nullable = true)
#  |-- eeg1090: double (nullable = true)
#  |-- eeg1091: double (nullable = true)
#  |-- eeg1092: double (nullable = true)
#  |-- eeg1093: double (nullable = true)
#  |-- eeg1094: double (nullable = true)
#  |-- eeg1095: double (nullable = true)
#  |-- eeg1096: double (nullable = true)
#  |-- eeg1097: double (nullable = true)
#  |-- eeg1098: double (nullable = true)
#  |-- eeg1099: double (nullable = true)
#  |-- eeg1100: double (nullable = true)
#  |-- eeg1101: double (nullable = true)
#  |-- eeg1102: double (nullable = true)
#  |-- eeg1103: double (nullable = true)
#  |-- eeg1104: double (nullable = true)
#  |-- eeg1105: double (nullable = true)
#  |-- eeg1106: double (nullable = true)
#  |-- eeg1107: double (nullable = true)
#  |-- eeg1108: double (nullable = true)
#  |-- eeg1109: double (nullable = true)
#  |-- eeg1110: double (nullable = true)
#  |-- eeg1111: double (nullable = true)
#  |-- eeg1112: double (nullable = true)
#  |-- eeg1113: double (nullable = true)
#  |-- eeg1114: double (nullable = true)
#  |-- eeg1115: double (nullable = true)
#  |-- eeg1116: double (nullable = true)
#  |-- eeg1117: double (nullable = true)
#  |-- eeg1118: double (nullable = true)
#  |-- eeg1119: double (nullable = true)
#  |-- eeg1120: double (nullable = true)
#  |-- eeg1121: double (nullable = true)
#  |-- eeg1122: double (nullable = true)
#  |-- eeg1123: double (nullable = true)
#  |-- eeg1124: double (nullable = true)
#  |-- eeg1125: double (nullable = true)
#  |-- eeg1126: double (nullable = true)
#  |-- eeg1127: double (nullable = true)
#  |-- eeg1128: double (nullable = true)
#  |-- eeg1129: double (nullable = true)
#  |-- eeg1130: double (nullable = true)
#  |-- eeg1131: double (nullable = true)
#  |-- eeg1132: double (nullable = true)
#  |-- eeg1133: double (nullable = true)
#  |-- eeg1134: double (nullable = true)
#  |-- eeg1135: double (nullable = true)
#  |-- eeg1136: double (nullable = true)
#  |-- eeg1137: double (nullable = true)
#  |-- eeg1138: double (nullable = true)
#  |-- eeg1139: double (nullable = true)
#  |-- eeg1140: double (nullable = true)
#  |-- eeg1141: double (nullable = true)
#  |-- eeg1142: double (nullable = true)
#  |-- eeg1143: double (nullable = true)
#  |-- eeg1144: double (nullable = true)
#  |-- eeg1145: double (nullable = true)
#  |-- eeg1146: double (nullable = true)
#  |-- eeg1147: double (nullable = true)
#  |-- eeg1148: double (nullable = true)
#  |-- eeg1149: double (nullable = true)
#  |-- eeg1150: double (nullable = true)
#  |-- eeg1151: double (nullable = true)
#  |-- eeg1152: double (nullable = true)
#  |-- eeg1153: double (nullable = true)
#  |-- eeg1154: double (nullable = true)
#  |-- eeg1155: double (nullable = true)
#  |-- eeg1156: double (nullable = true)
#  |-- eeg1157: double (nullable = true)
#  |-- eeg1158: double (nullable = true)
#  |-- eeg1159: double (nullable = true)
#  |-- eeg1160: double (nullable = true)
#  |-- eeg1161: double (nullable = true)
#  |-- eeg1162: double (nullable = true)
#  |-- eeg1163: double (nullable = true)
#  |-- eeg1164: double (nullable = true)
#  |-- eeg1165: double (nullable = true)
#  |-- eeg1166: double (nullable = true)
#  |-- eeg1167: double (nullable = true)
#  |-- eeg1168: double (nullable = true)
#  |-- eeg1169: double (nullable = true)
#  |-- eeg1170: double (nullable = true)
#  |-- eeg1171: double (nullable = true)
#  |-- eeg1172: double (nullable = true)
#  |-- eeg1173: double (nullable = true)
#  |-- eeg1174: double (nullable = true)
#  |-- eeg1175: double (nullable = true)
#  |-- eeg1176: double (nullable = true)
#  |-- eeg1177: double (nullable = true)
#  |-- eeg1178: double (nullable = true)
#  |-- eeg1179: double (nullable = true)
#  |-- eeg1180: double (nullable = true)
#  |-- eeg1181: double (nullable = true)
#  |-- eeg1182: double (nullable = true)
#  |-- eeg1183: double (nullable = true)
#  |-- eeg1184: double (nullable = true)
#  |-- eeg1185: double (nullable = true)
#  |-- eeg1186: double (nullable = true)
#  |-- eeg1187: double (nullable = true)
#  |-- eeg1188: double (nullable = true)
#  |-- eeg1189: double (nullable = true)
#  |-- eeg1190: double (nullable = true)
#  |-- eeg1191: double (nullable = true)
#  |-- eeg1192: double (nullable = true)
#  |-- eeg1193: double (nullable = true)
#  |-- eeg1194: double (nullable = true)
#  |-- eeg1195: double (nullable = true)
#  |-- eeg1196: double (nullable = true)
#  |-- eeg1197: double (nullable = true)
#  |-- eeg1198: double (nullable = true)
#  |-- eeg1199: double (nullable = true)
#  |-- eeg1200: double (nullable = true)
#  |-- eeg1201: double (nullable = true)
#  |-- eeg1202: double (nullable = true)
#  |-- eeg1203: double (nullable = true)
#  |-- eeg1204: double (nullable = true)
#  |-- eeg1205: double (nullable = true)
#  |-- eeg1206: double (nullable = true)
#  |-- eeg1207: double (nullable = true)
#  |-- eeg1208: double (nullable = true)
#  |-- eeg1209: double (nullable = true)
#  |-- eeg1210: double (nullable = true)
#  |-- eeg1211: double (nullable = true)
#  |-- eeg1212: double (nullable = true)
#  |-- eeg1213: double (nullable = true)
#  |-- eeg1214: double (nullable = true)
#  |-- eeg1215: double (nullable = true)
#  |-- eeg1216: double (nullable = true)
#  |-- eeg1217: double (nullable = true)
#  |-- eeg1218: double (nullable = true)
#  |-- eeg1219: double (nullable = true)
#  |-- eeg1220: double (nullable = true)
#  |-- eeg1221: double (nullable = true)
#  |-- eeg1222: double (nullable = true)
#  |-- eeg1223: double (nullable = true)
#  |-- eeg1224: double (nullable = true)
#  |-- eeg1225: double (nullable = true)
#  |-- eeg1226: double (nullable = true)
#  |-- eeg1227: double (nullable = true)
#  |-- eeg1228: double (nullable = true)
#  |-- eeg1229: double (nullable = true)
#  |-- eeg1230: double (nullable = true)
#  |-- eeg1231: double (nullable = true)
#  |-- eeg1232: double (nullable = true)
#  |-- eeg1233: double (nullable = true)
#  |-- eeg1234: double (nullable = true)
#  |-- eeg1235: double (nullable = true)
#  |-- eeg1236: double (nullable = true)
#  |-- eeg1237: double (nullable = true)
#  |-- eeg1238: double (nullable = true)
#  |-- eeg1239: double (nullable = true)
#  |-- eeg1240: double (nullable = true)
#  |-- eeg1241: double (nullable = true)
#  |-- eeg1242: double (nullable = true)
#  |-- eeg1243: double (nullable = true)
#  |-- eeg1244: double (nullable = true)
#  |-- eeg1245: double (nullable = true)
#  |-- eeg1246: double (nullable = true)
#  |-- eeg1247: double (nullable = true)
#  |-- eeg1248: double (nullable = true)
#  |-- eeg1249: double (nullable = true)
#  |-- eeg1250: double (nullable = true)

# %%
train_pre = train.rdd\
                 .map(lambda x: list(x[0:11])
                      + [min(x[11:]), max(x[11:]), sum(abs(egg) for egg in x[11:])/1250, float(np.median(x[11:]))])

# %%
schema = StructType([StructField("num_prev_so", IntegerType(), True),
                     StructField("mean_amp_prev_so", DoubleType(), True),
                     StructField("mean_duration_prev_so", DoubleType(), True),
                     StructField("amp_curr_so", DoubleType(), True),
                     StructField("duration_curr_so", IntegerType(), True),
                     StructField("curr_sleep_stage", IntegerType(), True),
                     StructField("time_elapsed_since_asleep", IntegerType(), True),
                     StructField("time_deep_sleep", IntegerType(), True),
                     StructField("time_light_sleep", IntegerType(), True),
                     StructField("time_rem_sleep", IntegerType(), True),
                     StructField("time_wake_sleep", IntegerType(), True),
                     StructField("egg_min", DoubleType(), True),
                     StructField("egg_max", DoubleType(), True),
                     StructField("egg_mean", DoubleType(), True),
                     StructField("egg_median", DoubleType(), True)
                    ])

# %%
train_pre_df = ss.createDataFrame(train_pre, schema)

# %%
train_pre_df.show(5)
# Out:
# +-----------+------------------+---------------------+-----------+----------------+----------------+-------------------------+---------------+----------------+--------------+---------------+-------------------+------------------+------------------+------------------+
# |num_prev_so|  mean_amp_prev_so|mean_duration_prev_so|amp_curr_so|duration_curr_so|curr_sleep_stage|time_elapsed_since_asleep|time_deep_sleep|time_light_sleep|time_rem_sleep|time_wake_sleep|            egg_min|           egg_max|          egg_mean|        egg_median|
# +-----------+------------------+---------------------+-----------+----------------+----------------+-------------------------+---------------+----------------+--------------+---------------+-------------------+------------------+------------------+------------------+
# |        237|           152.659|              341.523|    128.017|             429|               3|                    11379|           2730|            3780|             0|            480|           -258.302|211.59900000000002| 81.01330035543988|11.181550000000001|
# |        176|146.88299999999998|               338.04|    119.131|             196|               2|                     6721|           2580|            2100|             0|            480|           -97.9233|           70.1037|21.165725239919997|         -1.132195|
# |        456|           152.377|              335.629|    164.293|             417|               2|                    26832|           3240|            7440|          2130|            750|           -121.882|           117.155|41.784519187280054| 7.763739999999999|
# |         21|           139.721|              336.286|    159.237|             407|               3|                     1289|              0|              60|             0|            450|-110.45299999999999|           92.3682| 30.84454222112002|          -3.52191|
# |         72|           140.649|              349.875|    130.184|             297|               3|                     2262|            630|             960|             0|            450|-119.81200000000001|           105.522| 36.69490354160005|         -0.875058|
# +-----------+------------------+---------------------+-----------+----------------+----------------+-------------------------+---------------+----------------+--------------+---------------+-------------------+------------------+------------------+------------------+
# only showing top 5 rows
